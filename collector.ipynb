# %%
from datapull import *

sim_list = {}
sim_list['AAPL'] = StockData(ticker='AAPL')
sim_list['IBM'] = StockData(ticker='IBM')

for sim in sim_list.keys():
    sim_list[sim].get_financial_data()
    sim_list[sim].get_price_data()
    sim_list[sim].get_analyst_estimates()
    sim_list[sim].get_key_metrics()
    sim_list[sim].get_ratios()

# %%
sim_list['IBM'].ratios.head()
# Out:
#   symbol        date calendarYear period  currentRatio  quickRatio  cashRatio  \
# 0    IBM  2024-06-30         2024     Q2      1.089517    1.047895   0.488330
# 1    IBM  2024-03-31         2024     Q1      1.099361    1.061950   0.455752
# 2    IBM  2023-12-31         2023     Q4      0.935201    0.901175   0.383605
# 3    IBM  2023-09-30         2023     Q3      0.905215    0.859505   0.237110
# 4    IBM  2023-06-30         2023     Q2      1.059822    1.013656   0.288931
#
#    daysOfSalesOutstanding  daysOfInventoryOutstanding  operatingCycle  ...  \
# 0               73.415346                   15.433574       88.848920  ...
# 1               76.682340                   16.653435       93.335775  ...
# 2               78.023129                   14.687939       92.711068  ...
# 3               71.967058                   18.711547       90.678605  ...
# 4               75.256866                   19.370519       94.627385  ...
#
#    priceToSalesRatio  priceEarningsRatio  priceToFreeCashFlowsRatio  \
# 0          10.218285           21.965969                  99.347934
# 1          12.039281           27.120261                  45.722709
# 2           8.607053           11.374634                  37.269354
# 3           8.680573           18.788804                  46.182651
# 4           7.867388           19.227388                  56.600569
#
#    priceToOperatingCashFlowsRatio  priceCashFlowRatio  \
# 0                       77.997264           77.997264
# 1                       41.763511           41.763511
# 2                       33.527383           33.527383
# 3                       41.919637           41.919637
# 4                       46.151563           46.151563
#
#    priceEarningsToGrowthRatio  priceSalesRatio  dividendYield  \
# 0                    1.601685        10.218285       0.009532
# 1                   -0.529140        12.039281       0.008741
# 2                    0.123666         8.607053       0.010147
# 3                    2.514809         8.680573       0.011830
# 4                    0.272388         7.867388       0.012403
#
#    enterpriseValueMultiple  priceFairValue
# 0                54.486372        6.706999
# 1                87.418598        7.485150
# 2                59.800665        6.639115
# 3                53.088363        5.548481
# 4                49.344905        5.483889
#
# [5 rows x 58 columns]

# %%
sim_list['IBM'].key_metrics.head()
# Out:
#   symbol        date calendarYear period  revenuePerShare  netIncomePerShare  \
# 0    IBM  2024-06-30         2024     Q2        17.135949           1.992855
# 1    IBM  2024-03-31         2024     Q1        15.767553           1.749891
# 2    IBM  2023-12-31         2023     Q4        19.001859           3.594621
# 3    IBM  2023-09-30         2023     Q3        16.162528           1.866803
# 4    IBM  2023-06-30         2023     Q2        17.008187           1.739836
#
#    operatingCashFlowPerShare  freeCashFlowPerShare  cashPerShare  \
# 0                   2.244951              1.762493     17.341319
# 1                   4.545355              4.151766     21.017226
# 2                   4.878102              4.388324     14.717394
# 3                   3.346880              3.037937     12.026858
# 4                   2.899360              2.364111     17.912726
#
#    bookValuePerShare  ...  averagePayables  averageInventory  \
# 0          26.107058  ...     3.609500e+09      1.223000e+09
# 1          25.360881  ...     3.860000e+09      1.186500e+09
# 2          24.634306  ...     3.737000e+09      1.280000e+09
# 3          25.286200  ...     3.537000e+09      1.450000e+09
# 4          24.400566  ...     3.730000e+09      1.552000e+09
#
#    daysSalesOutstanding  daysPayablesOutstanding  daysOfInventoryOnHand  \
# 0             73.415346                45.412729              15.433574
# 1             76.682340                49.300763              16.653435
# 2             78.023129                52.274389              14.687939
# 3             71.967058                44.699064              18.711547
# 4             75.256866                48.161744              19.370519
#
#    receivablesTurnover  payablesTurnover  inventoryTurnover       roe  \
# 0             1.225902          1.981823           5.831442  0.076334
# 1             1.173673          1.825530           5.404290  0.069000
# 2             1.153504          1.721684           6.127476  0.145919
# 3             1.250572          2.013465           4.809864  0.073827
# 4             1.195904          1.868703           4.646236  0.071303
#
#    capexPerShare
# 0       0.482458
# 1       0.393589
# 2       0.489778
# 3       0.308943
# 4       0.535250
#
# [5 rows x 61 columns]

# %%
sim_list['IBM'].income_statement.head()
# Out:
#          date symbol period    revenues  costofrevenue  grossprofit  \
# 0  2024-06-29    IBM     Q2  7406000000     5126000000   8950000000
# 1  2024-03-30    IBM     Q1  7470000000     5239000000   7742000000
# 2  2023-03-30    IBM     Q1  7524000000     5310000000   7509000000
# 3  2022-09-29    IBM     Q3  7365000000     5168000000   7430000000
# 4  2022-06-29    IBM     Q2  7640000000     5398000000   8290000000
#
#    sellinggeneralandadministrativeexpense  researchanddevelopmentexpense  \
# 0                              4938000000                     1841000000
# 1                              4974000000                     1796000000
# 2                              4853000000                     1655000000
# 3                              4391000000                     1611000000
# 4                              4855000000                     1673000000
#
#    intellectualpropertyandcustomdevelopmentincome  otherincomeandexpense  ...  \
# 0                                       242000000          -2.330000e+08  ...
# 1                                       216000000          -3.170000e+08  ...
# 2                                       180000000          -2.450000e+08  ...
# 3                                       121000000           5.755000e+09  ...
# 4                                       176000000          -8.000000e+07  ...
#
#    othercomprehensiveincomereclassificationadjustmentforsaleofsecuritiesincludedinnetincomebeforetax  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    othercomprehensiveincomeavailableforsalesecuritiesadjustmentbeforetaxperiodincreasedecrease  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    othercomprehensiveincomereclassificationadjustmentonderivativesincludedinnetincomebeforetax  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    othercomprehensiveincomederivativesqualifyingashedgesbeforetaxperiodincreasedecrease  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    othercomprehensiveincomedefinedbenefitplansnetunamortizedgainlossarisingduringperiodbeforetax  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    othercomprehensiveincomeamortizationofdefinedbenefitplannetpriorservicecostcreditrecognizedinnetperiodicbenefitcostbeforetax  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    othercomprehensiveincomedefinedbenefitplansadjustmentbeforetaxperiodincreasedecrease  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    othercomprehensiveincomelossbeforetaxperiodincreasedecrease  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    othercomprehensiveincomelossnetoftaxperiodincreasedecrease  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    incomelossfromcontinuingoperationsbeforeincometaxesminorityinterestandincomelossfromequitymethodinvestments
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 82 columns]

# %%
sim_list['IBM'].balance_sheet.head()
# Out:
#          date symbol period  cashandcashequivalentsatcarryingvalue  \
# 0  2024-06-29    IBM     Q2                            12210000000
# 1  2024-03-30    IBM     Q1                            14603000000
# 2  2023-12-30    IBM     Q4                            13068000000
# 3  2023-09-29    IBM     Q3                             7257000000
# 4  2023-06-29    IBM     Q2                             9394000000
#
#    restrictedcash  \
# 0    2.268000e+09
# 1    1.620000e+08
# 2    2.100000e+07
# 3    1.900000e+07
# 4    3.100000e+07
#
#    debtsecuritiesavailableforsaleexcludingaccruedinterestcurrent  \
# 0                                       1.481000e+09
# 1                                       4.512000e+09
# 2                                       3.730000e+08
# 3                                       3.721000e+09
# 4                                       6.904000e+09
#
#    accountsreceivablenetcurrent  \
# 0                    5769000000
# 1                    6041000000
# 2                    7214000000
# 3                    5330000000
# 4                    5673000000
#
#    notesandloansreceivableandnetinvestmentinleaseheldforinvestmentnetcurrent  \
# 0                                       5.075000e+09
# 1                                       4.877000e+09
# 2                                       6.102000e+09
# 3                                       5.032000e+09
# 4                                                NaN
#
#    tradeandloansreceivablesheldforsalenetnotpartofdisposalgroup  \
# 0                                        723000000.0
# 1                                        644000000.0
# 2                                        692000000.0
# 3                                        593000000.0
# 4                                        865000000.0
#
#    otherreceivablesnetcurrent  ...  inventoryworkinprocessandrawmaterials  \
# 0                   757000000  ...                                    NaN
# 1                   760000000  ...                                    NaN
# 2                   640000000  ...                                    NaN
# 3                   842000000  ...                                    NaN
# 4                   838000000  ...                                    NaN
#
#    deferredtaxassetsnetnoncurrent  intangibleassetsnetexcludinggoodwill  \
# 0                             NaN                                   NaN
# 1                             NaN                                   NaN
# 2                             NaN                                   NaN
# 3                             NaN                                   NaN
# 4                             NaN                                   NaN
#
#    otherassetsnoncurrent  deferredcompensationliabilitycurrent  \
# 0                    NaN                                   NaN
# 1                    NaN                                   NaN
# 2                    NaN                                   NaN
# 3                    NaN                                   NaN
# 4                    NaN                                   NaN
#
#    otherliabilitiescurrent  treasurystockvalue  treasurystockshares  \
# 0                      NaN                 NaN                  NaN
# 1                      NaN                 NaN                  NaN
# 2                      NaN                 NaN                  NaN
# 3                      NaN                 NaN                  NaN
# 4                      NaN                 NaN                  NaN
#
#    deferredtaxassetsnetcurrent  commonstockincludingadditionalpaidincapital
# 0                          NaN                                          NaN
# 1                          NaN                                          NaN
# 2                          NaN                                          NaN
# 3                          NaN                                          NaN
# 4                          NaN                                          NaN
#
# [5 rows x 81 columns]

# %%
fred_list = ["DGS10","DGS2","DTB3","SP500"]
fred_data_list = {}

for item in fred_list:
    fred_data_list[item] = FredData(ticker=item)
for item in fred_list:
    fred_data_list[item].get_data()

# %%
fred_data_list['SP500'].data
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 fred_data_list['SP500'].financial_data
#
# AttributeError: 'FredData' object has no attribute 'financial_data'
